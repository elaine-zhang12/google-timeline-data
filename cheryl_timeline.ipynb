# %% [markdown]
# # Process Google Timeline Data

# %%
import os
from dotenv import load_dotenv

# VARIABLES
folder = "CB_data" # ONLY need to change this value

json_file = folder + "/location-history.json"
cluster_counts_file_path = folder + "/cluster_counts.csv"
cluster_data_file_path = folder + "/cluster_means.csv"
places_data_file_path = folder + "/places_info.csv"

load_dotenv()
# Make sure to create a .env file and store your API KEY
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
import json
import pandas as pd
import numpy as np
import requests
from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %%
def load_google_timeline(json_file):
    with open(json_file, "r", encoding="utf-8") as file:
        data = json.load(file)
    
    locations = []
    for entry in data:
        if "visit" in entry:
            visit_info = entry["visit"]
            top_candidate = visit_info.get("topCandidate", {})

            if "placeLocation" in top_candidate:
                latlon_str = top_candidate["placeLocation"].replace("geo:", "")
                lat, lon = map(float, latlon_str.split(",")) 
                
                start_time = entry.get("startTime", "")
                end_time = entry.get("endTime", "")

                locations.append((lat, lon, start_time, end_time))

    return pd.DataFrame(locations, columns=["latitude", "longitude", "start_time", "end_time"])


df = load_google_timeline(json_file)
df.head()
# Out:
#     latitude  longitude                     start_time  \
# 0  38.033553 -78.507977  2025-01-14T16:50:33.999-05:00
# 1  38.031619 -78.510846  2025-01-15T09:25:47.488-05:00
# 2  38.029297 -78.510103  2025-01-15T10:53:54.217-05:00
# 3  38.031619 -78.510846  2025-01-15T12:13:04.349-05:00
# 4  38.033553 -78.507977  2025-01-15T20:19:08.968-05:00
#
#                         end_time
# 0  2025-01-15T09:24:39.627-05:00
# 1  2025-01-15T10:53:54.217-05:00
# 2  2025-01-15T12:13:04.349-05:00
# 3  2025-01-15T15:18:36.354-05:00
# 4  2025-01-15T21:12:17.457-05:00

# %%
df['start_time'] = pd.to_datetime(df['start_time'])
df['end_time'] = pd.to_datetime(df['end_time'])
df['duration_time'] = df['end_time'] - df['start_time']
df.head()
# Out:
# C:\Users\chery\AppData\Local\Temp\ipykernel_19056\2510686417.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['start_time'] = pd.to_datetime(df['start_time'])
# C:\Users\chery\AppData\Local\Temp\ipykernel_19056\2510686417.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['end_time'] = pd.to_datetime(df['end_time'])
#     latitude  longitude                        start_time  \
# 0  38.033553 -78.507977  2025-01-14 16:50:33.999000-05:00
# 1  38.031619 -78.510846  2025-01-15 09:25:47.488000-05:00
# 2  38.029297 -78.510103  2025-01-15 10:53:54.217000-05:00
# 3  38.031619 -78.510846  2025-01-15 12:13:04.349000-05:00
# 4  38.033553 -78.507977  2025-01-15 20:19:08.968000-05:00
#
#                            end_time           duration_time
# 0  2025-01-15 09:24:39.627000-05:00  0 days 16:34:05.628000
# 1  2025-01-15 10:53:54.217000-05:00  0 days 01:28:06.729000
# 2  2025-01-15 12:13:04.349000-05:00  0 days 01:19:10.132000
# 3  2025-01-15 15:18:36.354000-05:00  0 days 03:05:32.005000
# 4  2025-01-15 21:12:17.457000-05:00  0 days 00:53:08.489000

# %% [markdown]
# ### Find Clusters based on Longitude and Latitude

# %%
def cluster_locations(df, eps=50, min_samples=2):
    coords = df[["latitude", "longitude"]].values
    db = DBSCAN(eps=eps / 6371000, min_samples=min_samples, metric="haversine").fit(np.radians(coords))
    df["cluster"] = db.labels_
    return df

df_clusters = cluster_locations(df)
df_clusters["duration_time"] = pd.to_timedelta(df_clusters["duration_time"])

# %%
df_clusters.to_csv(cluster_counts_file_path)

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

silhouette = silhouette_score(df[["latitude", "longitude"]], df_clusters['cluster'])
db_index = davies_bouldin_score(df[["latitude", "longitude"]], df_clusters['cluster'])
ch_index = calinski_harabasz_score(df[["latitude", "longitude"]], df_clusters['cluster'])

print(f"Silhouette Score: {silhouette:.2f}")
print(f"Davies-Bouldin Index: {db_index:.2f}")
print(f"Calinski-Harabasz Index: {ch_index:.2f}")
# Out:
# Silhouette Score: 0.81
# Davies-Bouldin Index: 1.02
# Calinski-Harabasz Index: 66.17

# %%
import folium

def plot_clusters_folium(df):
    # map_center = [df["latitude"].mean(), df["longitude"].mean()]
    m = folium.Map(location=[38.028028, -78.508516], zoom_start=14)

    # Define colors for clusters
    cluster_colors = {
        -1: "gray"  # Noise
    }
    unique_clusters = df["cluster"].unique()
    cmap = plt.cm.get_cmap("tab10", len(unique_clusters))

    for i, cluster in enumerate(unique_clusters):
        if cluster not in cluster_colors:
            cluster_colors[cluster] = f"#{''.join(np.random.choice(list('0123456789ABCDEF'), 6))}" 
    
    # adding points to a map
    for _, row in df.iterrows():
        folium.CircleMarker(
            location=[row["latitude"], row["longitude"]],
            radius=5,
            color=cluster_colors[row["cluster"]],
            fill=True,
            fill_color=cluster_colors[row["cluster"]],
            fill_opacity=0.6,
        ).add_to(m)

    return m

plot_clusters_folium(df_clusters)
# Out:
# C:\Users\chery\AppData\Local\Temp\ipykernel_19056\2389770946.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(unique_clusters))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7b2e2995f860a36992b130b00eba398 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7b2e2995f860a36992b130b00eba398&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7b2e2995f860a36992b130b00eba398 = L.map(
#                 &quot;map_a7b2e2995f860a36992b130b00eba398&quot;,
#                 {
#                     center: [38.028028, -78.508516],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_433a27e4cbf83254ef838f323bd5ce73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_433a27e4cbf83254ef838f323bd5ce73.addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_7b47466dba4df4b1da8572b28f50fdaf = L.circleMarker(
#                 [38.033553, -78.507977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1F3E92&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1F3E92&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_1543ebb9c1a9f0a24dabc3e6b3ca7e9d = L.circleMarker(
#                 [38.031619, -78.510846],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#86592C&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#86592C&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_80dbde8035da090b3c0bb0208b9a601f = L.circleMarker(
#                 [38.029297, -78.510103],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#9D539E&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#9D539E&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_4bd6dde0f6bb02c3350eae0e1d4430ef = L.circleMarker(
#                 [38.031619, -78.510846],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#86592C&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#86592C&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_ac9f54f9b37315f53086a9d1abc46dfd = L.circleMarker(
#                 [38.033553, -78.507977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1F3E92&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1F3E92&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_284f1dbd68c50bb39e6a7df869279cf0 = L.circleMarker(
#                 [38.031103, -78.513688],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#F855C0&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#F855C0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a7b2e2995f860a36992b130b00eba398);
#
#
#             var circle_marker_13bb66dedba8d3ed26b25405558dca32 = L.circleMarker(

# %%
print(df_clusters['cluster'].nunique())
# Out:
# 43

# %%
df_filtered = df_clusters[df_clusters["cluster"] != -1]
cluster_means = df_filtered.groupby("cluster")[["latitude", "longitude"]].mean().reset_index()
cluster_durations = df_filtered.groupby("cluster")["duration_time"].sum().reset_index()
cluster_means = cluster_means.merge(cluster_durations, on="cluster")
cluster_means.to_csv(cluster_data_file_path, index=False)

# %%
# plot ONLY the cluster means on the map
plot_clusters_folium(cluster_means)
# Out:
# C:\Users\chery\AppData\Local\Temp\ipykernel_19056\2389770946.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(unique_clusters))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83eac950fa1598eb68134704c704fdf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83eac950fa1598eb68134704c704fdf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83eac950fa1598eb68134704c704fdf6 = L.map(
#                 &quot;map_83eac950fa1598eb68134704c704fdf6&quot;,
#                 {
#                     center: [38.028028, -78.508516],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3863cd15aa48ac77b22cdcf61ad7b79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3863cd15aa48ac77b22cdcf61ad7b79.addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_230d18b0327b16a93fd211c73d71f35b = L.circleMarker(
#                 [38.033553, -78.507977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#399B88&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#399B88&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_84df30a5d975843d64d8f0ecd2f951b4 = L.circleMarker(
#                 [38.031619, -78.510846],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#A3776C&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#A3776C&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_9ef682b1817dcf9481deaad7d7e82619 = L.circleMarker(
#                 [38.02929709243697, -78.51009774789917],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7DBCED&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7DBCED&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_607a9a8e03bd1b8b984917edde5b6c84 = L.circleMarker(
#                 [38.031102999999995, -78.513688],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#894167&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#894167&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_b37b3a54c2efefce9b0e2578295f9dcb = L.circleMarker(
#                 [38.052777150000004, -78.5013018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#DABC07&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#DABC07&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_9bb2b8e76cf42375bea27b5c65ff0662 = L.circleMarker(
#                 [38.069505, -78.48403],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#EED540&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#EED540&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_83eac950fa1598eb68134704c704fdf6);
#
#
#             var circle_marker_7fb4d2a841f148ee9396cce38fd1

# %% [markdown]
# ### Use Google Places API to find Location Names

# %%
import requests

# Define the API endpoint
url = "https://places.googleapis.com/v1/places:searchNearby"

# Define the headers
headers = {
    "Content-Type": "application/json",
    "X-Goog-Api-Key": GOOGLE_API_KEY,  # Replace with your actual API key
    "X-Goog-FieldMask": "places.displayName,places.formattedAddress,places.types,places.id"
}

# Define the payload
data = {
    "maxResultCount": 1,
    "locationRestriction": {
        "circle": {
            "center": {
                "latitude": 38.904423,
                "longitude": -77.2036175000000
            },
            "radius": 20.0
        }
    }
}
# Make the POST request
response = requests.post(url, headers=headers, json=data)
print(response.json())
# Out:
# {'places': [{'id': 'ChIJHX0M4tdKtokRu7PPetQjRTY', 'types': ['grocery_store', 'liquor_store', 'supermarket', 'food_store', 'food', 'market', 'health', 'point_of_interest', 'store', 'establishment'], 'formattedAddress': '7514 Leesburg Pike, Falls Church, VA 22043, USA', 'displayName': {'text': "Trader Joe's", 'languageCode': 'en'}}]}

# %%
def get_place_info(lat, lon):
    url = "https://places.googleapis.com/v1/places:searchNearby"

    # Define the headers
    headers = {
        "Content-Type": "application/json",
        "X-Goog-Api-Key": GOOGLE_API_KEY,
        "X-Goog-FieldMask": "places.displayName,places.formattedAddress,places.types,places.id"
    }

    # Define the payload
    data = {
        "maxResultCount": 1,
        "locationRestriction": {
            "circle": {
                "center": {
                    "latitude": lat,
                    "longitude": lon
                },
                "radius": 20.0
            }
        }
    }
    response = requests.post(url, headers=headers, json=data)
    return response.json()

# %%
cluster_means = pd.read_csv(cluster_data_file_path)
results = []

for index, row in cluster_means.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    time = row['duration_time']
    cluster_id = row['cluster']
    
    place_data = get_place_info(lat, lon)
    
    places_info = place_data.get('places', [])
    
    # Loop through the places and store the relevant info
    for place in places_info:
        results.append({
            'cluster_id': cluster_id,
            'latitude': lat,
            'longitude': lon,
            'total_duration_time': time,
            'place_id': place.get('id', ''),
            'place_types': place.get('types', []),
            'place_address': place.get('formattedAddress', ''),
            'place_name': place.get('displayName', {}).get('text', '')
        })


place_info_df = pd.DataFrame(results)
place_info_df.head()
# Out:
#    cluster_id   latitude  longitude      total_duration_time  \
# 0           0  38.033553 -78.507977   6 days 06:03:37.902000
# 1           1  38.031619 -78.510846   3 days 00:12:01.343000
# 2           2  38.029297 -78.510098  34 days 03:47:25.004000
# 3           3  38.031103 -78.513688   0 days 13:37:11.962000
# 4           4  38.052777 -78.501302   0 days 08:39:26.891000
#
#                       place_id  \
# 0  ChIJ3cRJt0iGs4kRRliLzMIIUUA
# 1  ChIJB1s6kd6Hs4kRJhuNmO73ZLk
# 2  ChIJjR--lIeHs4kRWTwypENqnhk
# 3  ChIJ83CLDFyGs4kRlpbwbea2AWc
# 4  ChIJI5T2nbeHs4kRuLewu_1gO8g
#
#                                          place_types  \
# 0     [university, point_of_interest, establishment]
# 1                 [point_of_interest, establishment]
# 2  [apartment_building, point_of_interest, establ...
# 3  [stadium, sports_complex, sports_activity_loca...
# 4  [shopping_mall, point_of_interest, establishment]
#
#                                        place_address  \
# 0                           Charlottesville, VA, USA
# 1  85 Engineer's Way, Charlottesville, VA 22903, USA
# 2  112 Montebello Cir, Charlottesville, VA 22903,...
# 3    1815 Stadium Rd, Charlottesville, VA 22903, USA
# 4    1117 Emmet St N, Charlottesville, VA 22903, USA
#
#                          place_name
# 0            University of Virginia
# 1                         Rice Hall
# 2  112 Montebello Circle Apartments
# 3                     Scott Stadium
# 4     Barracks Road Shopping Center

# %%
place_info_df.to_csv(places_data_file_path)
